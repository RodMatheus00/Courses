# %% [markdown]
# # Operadores

# %% [markdown]
# Operadores são estruturas utilizadas na comparação/manuseio de objetos e variáveis. Retornam valores booleanos.

# %% [markdown]
# ## Operadores de Comparação
#
# Utilizados para comparar os **valores** de entre objetos.

# %% [markdown]
# ### Maior que: `>`
#
# Retorna `True` quando o operando da esquerda é maior que o operando da direita.

# %%
print(5 > 4)

print(4 > 5)

print(5 > 5.0)
# Out:
# True
# False
# False

# %% [markdown]
# ### Maior ou igual que: `>=`
#
# Retorna `True` quando o operando da esquerda é maior ou igual ao operando da direita.

# %%
print(5 >= 8)

print(8 >= 5)

print(8 >= 8.0)
# Out:
# False
# True
# True

# %% [markdown]
# ### Menor que: `<`
#
# Retorna `True` quando o operando da esquerda é menor que o operando da direita.

# %%
print(4 < 5)

print(5 < 4)
# Out:
# True
# False

# %% [markdown]
# ### Menor ou igual que: `<=`
#
# Retorna `True` quando o operando da esquerda é menor ou igual ao operando da direita.

# %%
print(4 <= 4)

print(4 <= 6)
# Out:
# True
# True

# %% [markdown]
# ### Igualdade: `==`
#
# Retorna `True` quando ambos operandos são iguais.

# %%
print(4 == 6)

print(6 == 6)
# Out:
# False
# True

# %% [markdown]
# ### Diferença: `!=`
#
# Retorna `True` quando ambos operandos são diferentes.

# %%
print(4 != 5)

print(5 != 5)
# Out:
# True
# False

# %% [markdown]
# ## Obs:
#
# Também funcionam para variáveis!

# %%
v1 = "Python"

print(v1 == "Python")
# Out:
# True

# %% [markdown]
# ## Operadores de Identidade
#
# Utilizados para comparar se dois objetos **são os mesmos**.

# %% [markdown]
# ### Is: `is`
#
# Retorna `True` se os dois objetos de fato forem os mesmos, ou seja, locarizarem-se no mesmo local da memória.

# %%
v2 = [10, 20 ,30]

v3 = [10, 20 ,30]

print(v2 is v3)

print(id(v2))
print(id(v3))

v2[0] = 150

print(v2)
print(v3)
# Out:
# False
# 140367324469888
# 140367324469504
# [150, 20, 30]
# [10, 20, 30]

# %%
v4 = v5 = [1,2,3,4]

print(id(v4))
print(id(v5))

print(v4 is v5)

v4[0] = 150

print(v4)
print(v5)
# Out:
# 140367324440128
# 140367324440128
# True
# [150, 2, 3, 4]
# [150, 2, 3, 4]

# %% [markdown]
# ### Is not: `is not`
#
# Retorna `True` se os dois objetos **não** forem os mesmos, ou seja, locarizarem-se em locais diferentes da memória.

# %%
print(v2 is not v3)

print(v4 is not v5)
# Out:
# True
# False

# %% [markdown]
# ## Operadores de Filiação
#
# Utilizados para verificar se um objeto pertence a (está contido em) outro objeto.

# %% [markdown]
# ### In: `in`
#
# > ob1 in obj2
#
# Retorna `True` se `obj1` estiver contido em `obj2`.

# %%
print(150 in v4)

print(25 in v4)
# Out:
# True
# False

# %% [markdown]
# ### Not in: `not in`
#
# > ob1 not in obj2
#
# Retorna `True` se `obj1` **não** estiver contido em `obj2`.

# %%
print(150 not in v4)

print(25 not in v4)
# Out:
# False
# True

# %% [markdown]
# ### Dicionários:

# %%
d = {"Linguagem": "Python", "Aprendendo": True}

print(d)
# Out:
# {'Linguagem': 'Python', 'Aprendendo': True}

# %%
print("Linguagem" in d)

print("Python" in d.values())
# Out:
# True
# True

# %% [markdown]
# ## Operadores Lógicos
#
# Utilizados para concatenar comparações simples, criando então comparações compostas.

# %% [markdown]
# ### And: `and`
#
# > `expr1` and `exp2`
#
# Retorna `True` se ambas expressões forem verdadeiras.

# %%
print(5 > 2 and 6 > 4)

print((10 <= 100) and (55 != 55) and (89 > 5))
# Out:
# True
# False

# %% [markdown]
# ### Or: `or`
#
# > `expr1` or `exp2`
#
# Retorna `True` se alguma das expressões for verdadeira.

# %%
print(5 > 2 or 6 > 4)

print((10 <= 100) or (55 != 55))

print((10 >= 100) or (55 != 55))
# Out:
# True
# True
# False

# %% [markdown]
# ### Not: `not`
#
# > not `expr1`
#
# *Nega* logicamente a expressão, ou seja, altera seu valor lógico para seu oposto.

# %%
print(not True)
print(not False)

print(not ((5 > 2) or (6 < 4)))
# Out:
# False
# True
# False
